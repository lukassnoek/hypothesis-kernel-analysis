# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor']= 'white'

# %%
df = pd.read_csv('../results/noise_ceiling.tsv', sep='\t', index_col=0)
ax = sns.catplot(x='emotion', y='noise_ceiling', col='ethn', row='sub_split', data=df)

# %%
df
# Out:
#     noise_ceiling        sd   emotion ethn sub_split trial_split
# 0        0.855939  0.004211     anger   WC     train       train
# 1        0.866852  0.003230   disgust   WC     train       train
# 2        0.876974  0.003178      fear   WC     train       train
# 3        0.941909  0.002527     happy   WC     train       train
# 4        0.877466  0.003746   sadness   WC     train       train
# ..            ...       ...       ...  ...       ...         ...
# 1        0.810233  0.002245   disgust  all       all         all
# 2        0.820546  0.002418      fear  all       all         all
# 3        0.923630  0.001645     happy  all       all         all
# 4        0.852035  0.002059   sadness  all       all         all
# 5        0.873207  0.001869  surprise  all       all         all
#
# [162 rows x 6 columns]
